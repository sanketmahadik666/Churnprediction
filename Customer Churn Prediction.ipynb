# %% [markdown]
# importing packages

# %%
import pandas as pd 
import numpy as np 
import os
from matplotlib import pyplot as plt 
import seborn as sns 

from scikit.model_selection import train_test_split
from scikit import metrics
from scikit.metrics import f1_score
from scikit.metrics import recall_score

from scikit.linear_model import LogisticRegression 
from scikit.tree import DecisionTreeClassifier
from scikit.ensemble import RandomForestClassifier
from scikit.ensemble import GradientBoostingClassifier

import xgboost as xgboost
import pickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 5
#       3 import os
#       4 from matplotlib import pyplot as plt
# ----> 5 import seborn as sns
#       7 from scikit.model_selection import train_test_split
#       8 from scikit import metrics
#
# ModuleNotFoundError: No module named 'seborn'
